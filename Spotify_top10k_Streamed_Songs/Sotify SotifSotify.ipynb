# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

pwd = os.getcwd()

# %%
def GetData(file_name = str, df_name = str):
    if '.csv' in file_name:
        globals()[df_name] = pd.read_csv(f'{pwd}/{file_name}')
        return 
    if '.excel' in file_name:
        globals()[df_name] = pd.read_excel(f'{pwd}/{file_name}')
        return
    if '.json' in file_name:
        globals()[df_name] = pd.read_json(f'{pwd}/{file_name}')
        return

# %%
GetData('Spotify_final_dataset.csv', df_name = 'dataSet')
dataSet
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# ...

# %%
data_modified = dataSet[['Song Name', 'Total Streams']].copy().set_index('Song Name').head(10).squeeze().copy()

# %%
plt.figure(figsize = (20,20))
sns.barplot(y= top_10.index, x= top_10.values)
plt.title("Top 10 Streamed Songs", size=20)
plt.ylabel("Song", size=20)
plt.xlabel("Amount of Stream", size=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()
